# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
path = r"."

# %%
dfStartap = pd.read_csv(path + "\Startup.csv")
dfStartap
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit
# 0   165349.20       136897.80        471784.10  192261.83
# 1   162597.70       151377.59        443898.53  191792.06
# 2   153441.51       101145.55        407934.54  191050.39
# 3   144372.41       118671.85        383199.62  182901.99
# 4   142107.34        91391.77        366168.42  166187.94
# 5   131876.90        99814.71        362861.36  156991.12
# 6   134615.46       147198.87        127716.82  156122.51
# 7   130298.13       145530.06        323876.68  155752.60
# 8   120542.52       148718.95        311613.29  152211.77
# 9   123334.88       108679.17        304981.62  149759.96
# 10  101913.08       110594.11        229160.95  146121.95
# 11  100671.96        91790.61        249744.55  144259.40
# 12   93863.75       127320.38        249839.44  141585.52
# 13   91992.39       135495.07        252664.93  134307.35
# 14  119943.24       156547.42        256512.92  132602.65
# ...

# %%
dfStartap.plot.scatter(x='Marketing Spend', y='Profit')
dfStartap.plot.scatter(x='R&D Spend', y='Profit')
dfStartap.plot.scatter(x='Administration', y='Profit')
# Out:
# <Axes: xlabel='Administration', ylabel='Profit'>

# %%
X = dfStartap[['Administration','R&D Spend','Marketing Spend']]
y = dfStartap['Profit']
X_train, X_test, y_train, y_test = train_test_split(X, y)

model = LinearRegression()
model.fit(X_train, y_train)

B0 = model.intercept_
B1, B2, B3 = model.coef_

print(B1, B2, B3)
# Out:
# -0.006343920735182113 0.7705084573859223 0.03820383841893018

# %%
model.coef_
# Out:
# array([-0.00634392,  0.77050846,  0.03820384])

# %%
sns.regplot(x="Marketing Spend", y="Profit", data=dfStartap)
# Out:
# <Axes: xlabel='Marketing Spend', ylabel='Profit'>
